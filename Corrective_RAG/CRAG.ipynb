# %%
# !pip install -q -U llama-index llama-index-tools-tavily-research llama-index-readers-file llama-index-embeddings-huggingface llama-index-llms-gemini llama-index-embeddings-gemini
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 65.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 65.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 62.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 28.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.3/163.3 kB 17.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.4/137.4 kB 18.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 37.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.1/267.1 kB 15.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.0/136.0 kB 14.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 73.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.8/30.8 MB 19.0 MB/s eta 0:00:00
# ...

# %%
import os
GOOGLE_API_KEY = "AIzaSyB7EFUSkcMHDEV_ikq58pofrmoZv4tOmsU" # add your GOOGLE API key here
os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY

TAVILY_API_KEY = "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"

# %%
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.core import Settings

model_name = "jinaai/jina-embeddings-v2-base-en"
Settings.embed_model = HuggingFaceEmbedding(
    model_name=model_name
)
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/117 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/72.1k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/275M [00:00<?, ?B/s]
# ...

# %%
from llama_index.embeddings.gemini import GeminiEmbedding
from llama_index.llms.gemini import Gemini

# gemini_embedding_model = GeminiEmbedding(api_key=GOOGLE_API_KEY, model_name="models/embedding-001")
# Settings.embed_model = gemini_embedding_model

llm = Gemini()
Settings.llm = llm

# %%
from llama_index.core import SimpleDirectoryReader

reader = SimpleDirectoryReader(
    input_files=["/content/blade runner 2049.pdf"]
)

documents = reader.load_data()

# %%
from base import CorrectiveRAGPack

# %%
corrective_rag = CorrectiveRAGPack(documents, TAVILY_API_KEY)

# %%
corrective_rag.llm
# Out:
# Gemini(callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x7c795ace9ed0>, system_prompt=None, messages_to_prompt=<function messages_to_prompt at 0x7c7a76561870>, completion_to_prompt=<function default_completion_to_prompt at 0x7c7a763f80d0>, output_parser=None, pydantic_program_mode=<PydanticProgramMode.DEFAULT: 'default'>, query_wrapper_prompt=None, model_name='models/gemini-pro', temperature=0.1, max_tokens=2048, generate_kwargs={})

# %%
response = corrective_rag.run("Who are the characters?", similarity_top_k=4)

# %%
response.response
# Out:
# 'K, Tech, Joi, Niander Wallace, Rachael, Luv, Mariette, Freysa, Deckard'

# %%
response = corrective_rag.run("Explain the theme of the movie?", similarity_top_k=4)

# %%
response.response
# Out:
# 'The theme of the movie is that the moral arc of the universe does not bend towards justice, no matter how much we want it to.'

# %%
response = corrective_rag.run("How many male and female characters are in the movie?", similarity_top_k=4)

# %%
response.response
# Out:
# 'The provided context does not specify the number of male and female characters in any particular movie.'

# %%
response = corrective_rag.run("Does the script pass the Bechdel test?", similarity_top_k=4)

# %%
response.response
# Out:
# 'The provided context does not mention any specific script, so I cannot determine whether it passes the Bechdel test.'

# %%
response = corrective_rag.run("What is the role of Deckard in the movie?", similarity_top_k=4)

# %%
response.response
# Out:
# 'Deckard is a Blade Runner of the Los Angeles Police Department who is assigned to retire four replicants who stole a ship and illegally landed on Earth to find their creator, Dr. Eldon Tyrell.'

# %%
response = corrective_rag.run("How does the Wallace Corporation view replicants in the movie?", similarity_top_k=4)

# %%
response.response
# Out:
# 'The Wallace Corporation views replicants as an opportunity to harness the biological imperative in order to conquer the stars and achieve a higher state of existence.'

# %%
response = corrective_rag.run("Who is the child that Rachel had in the movie?", similarity_top_k=4)

# %%
response.response
# Out:
# 'The provided context does not mention anything about Rachel having a child in the movie.'

# %%
response = corrective_rag.run("What is the significance of the unicorn in the movie?", similarity_top_k=4)

# %%
response.response
# Out:
# "The unicorn in the movie Blade Runner symbolizes Deckard's dreams and his desire to escape with Rachel, but also that she will not live."

# %%
response = corrective_rag.run("How does K's character evolve throughout the movie?", similarity_top_k=4)

# %%
response.response
# Out:
# "The provided context does not mention how K's character evolves throughout the movie."
